# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 读取数据
data = pd.read_excel("D:\桌面\Train.xlsx").sample(frac=0.1, random_state=0)

# 将训练数据和测试数据分开
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# 训练XGBoost模型
xgb_model = xgb.XGBRegressor()
xgb_model.fit(X_train, y_train)

# 在测试集上进行预测
y_pred = xgb_model.predict(X_test)

# 计算MAE、RMSE和MAPE
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# 显示结果
print('MAE: %.4f' % mae)
print('RMSE: %.4f' % rmse)
print('MAPE: %.4f%%' % mape)
#0.1样本数量，未用十折交叉验证（XGBoost）
# Out:
# MAE: 3140.0976
# RMSE: 8112.0882
# MAPE: 181.5343%

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 读取数据
data = pd.read_excel("D:\桌面\Train.xlsx")

# 将训练数据和测试数据分开
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# 训练XGBoost模型
xgb_model = xgb.XGBRegressor()
xgb_model.fit(X_train, y_train)

# 在测试集上进行预测
y_pred = xgb_model.predict(X_test)

# 计算MAE、RMSE和MAPE
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# 显示结果
print('MAE: %.4f' % mae)
print('RMSE: %.4f' % rmse)
print('MAPE: %.4f%%' % mape)
#所有样本，未用十折交叉验证（XGBoost）
# Out:
# MAE: 3294.5518
# RMSE: 9128.3996
# MAPE: 187.8078%

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 读取数据
data = pd.read_excel("D:\桌面\Train.xlsx")

# 将训练数据和测试数据分开
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# 进行十折交叉验证
kf = KFold(n_splits=10, shuffle=True, random_state=0)

mae_list = []
rmse_list = []
mape_list = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # 训练XGBoost模型
    xgb_model = xgb.XGBRegressor()
    xgb_model.fit(X_train, y_train)

    # 在测试集上进行预测
    y_pred = xgb_model.predict(X_test)

    # 计算MAE、RMSE和MAPE
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

    mae_list.append(mae)
    rmse_list.append(rmse)
    mape_list.append(mape)

# 显示结果
print('MAE: %.4f' % np.mean(mae_list))
print('RMSE: %.4f' % np.mean(rmse_list))
print('MAPE: %.4f%%' % np.mean(mape_list))
#所有样本，使用十折交叉验证（XGBoost）
# Out:
# [23:32:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:32:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:32:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:33:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:33:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:33:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:33:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:33:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:33:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# [23:33:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_iter" } are not used.
#
# MAE: 3389.8637
# RMSE: 11627.1515
# MAPE: 211.6937%

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 读取数据
data = pd.read_excel("D:\桌面\Train.xlsx").sample(frac=0.1, random_state=0)

# 将训练数据和测试数据分开
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# 进行十折交叉验证
kf = KFold(n_splits=10, shuffle=True, random_state=0)

mae_list = []
rmse_list = []
mape_list = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # 训练XGBoost模型
    xgb_model = xgb.XGBRegressor()
    xgb_model.fit(X_train, y_train)

    # 在测试集上进行预测
    y_pred = xgb_model.predict(X_test)

    # 计算MAE、RMSE和MAPE
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

    mae_list.append(mae)
    rmse_list.append(rmse)
    mape_list.append(mape)

# 显示结果
print('MAE: %.4f' % np.mean(mae_list))
print('RMSE: %.4f' % np.mean(rmse_list))
print('MAPE: %.4f%%' % np.mean(mape_list))
#0。1样本，使用十折交叉验证（XGBoost）
# Out:
# MAE: 2990.8379
# RMSE: 6861.8811
# MAPE: 161.5449%

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error


# 读取数据
data = pd.read_excel("D:\桌面\Train.xlsx").sample(frac=0.1, random_state=0)

# 数据归一化
scaler = MinMaxScaler()
X = data.iloc[:, :-1]
X_scaled = scaler.fit_transform(X)
y = data.iloc[:, -1]

# 特征选择
selector = SelectKBest(chi2, k=10)
X_new = selector.fit_transform(X_scaled, y)

# 进行十折交叉验证
kf = KFold(n_splits=10, shuffle=True, random_state=0)

mae_list = []
rmse_list = []
mape_list = []

for train_index, test_index in kf.split(X_new):
    X_train, X_test = X_new[train_index], X_new[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # 训练XGBoost模型
    xgb_model = xgb.XGBRegressor(max_iter=1000)
    xgb_model.fit(X_train, y_train)

    # 在测试集上进行预测
    y_pred = xgb_model.predict(X_test)

    # 计算MAE、RMSE和MAPE
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

    mae_list.append(mae)
    rmse_list.append(rmse)
    mape_list.append(mape)

# 显示结果
print('MAE: %.4f' % np.mean(mae_list))
print('RMSE: %.4f' % np.mean(rmse_list))
print('MAPE: %.4f%%' % np.mean(mape_list))
#0。1样本，使用十折交叉验证（XGBoost）(进行了特征选择)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 11>()
#       8 data = pd.read_excel("D:\桌面\Train.xlsx").sample(frac=0.1, random_state=0)
#      10 # 数据归一化
# ---> 11 scaler = MinMaxScaler()
#      12 X = data.iloc[:, :-1]
#      13 X_scaled = scaler.fit_transform(X)
#
# NameError: name 'MinMaxScaler' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# 读取数据并抽样
data = pd.read_excel("D:\桌面\Train.xlsx").sample(frac=0.1, random_state=0)

# 数据归一化
scaler = MinMaxScaler()
X = data.iloc[:, :-1]
X_scaled = scaler.fit_transform(X)
y = data.iloc[:, -1]

# 特征选择
selector = SelectKBest(chi2, k=10)
X_new = selector.fit_transform(X_scaled, y)

# 训练模型并进行十折交叉验证
n_splits = 10
kf = KFold(n_splits=n_splits, shuffle=True, random_state=0)
mae_list = []
rmse_list = []
mape_list = []
for train_index, test_index in kf.split(X_new):
    X_train, X_test = X_new[train_index], X_new[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    rf_model = RandomForestRegressor()
    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict(X_test)
    mae_list.append(mean_absolute_error(y_test, y_pred))
    rmse_list.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    mape_list.append(np.mean(np.abs((y_test - y_pred) / y_test)) * 100)

# 显示结果
print('MAE: %.4f' % np.mean(mae_list))
print('RMSE: %.4f' % np.mean(rmse_list))
print('MAPE: %.4f%%' % np.mean(mape_list))
#0.1样本，使用十折交叉验证（RF）（进行了特征选择）
# Out:
# MAE: 2752.6732
# RMSE: 6361.6095
# MAPE: 159.5830%
